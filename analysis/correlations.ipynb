=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2118 # Add the markers here as PairGrid has figured out how many levels of the
#    2119 # hue variable are needed and we don't want to duplicate that process
#    2120 if markers is not None:
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/seaborn/axisgrid.py:1358, in PairGrid.__init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1356 if despine:
#    1357     utils.despine(fig=fig)
# -> 1358 self.tight_layout(pad=layout_pad)
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/seaborn/axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
#     116 if self._tight_layout_pad is not None:
#     117     kwargs.setdefault("pad", self._tight_layout_pad)
# --> 118 self._figure.tight_layout(*args, **kwargs)
#     119 return self
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/figure.py:3494, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3492 previous_engine = self.get_layout_engine()
#    3493 self.set_layout_engine(engine)
# -> 3494 engine.execute(self)
#    3495 if not isinstance(previous_engine, TightLayoutEngine) \
#    3496         and previous_engine is not None:
#    3497     _api.warn_external('The figure layout has changed to tight')
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/layout_engine.py:175, in TightLayoutEngine.execute(self, fig)
#     173 renderer = fig._get_renderer()
#     174 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 175     kwargs = get_tight_layout_figure(
#     176         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     177         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     178         rect=info['rect'])
#     179 if kwargs:
#     180     fig.subplots_adjust(**kwargs)
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/_tight_layout.py:293, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     290     if top is not None:
#     291         top -= (1 - kwargs["top"])
# --> 293     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     294                                       shape=(max_nrows, max_ncols),
#     295                                       span_pairs=span_pairs,
#     296                                       subplot_list=subplot_list,
#     297                                       ax_bbox_list=ax_bbox_list,
#     298                                       pad=pad, h_pad=h_pad, w_pad=w_pad,
#     299                                       rect=(left, bottom, right, top))
#     301 return kwargs
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/artist.py:1415, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409 """
#    1410 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1411 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1412 when encountering third-party subclasses that do not support it.
#    1413 """
#    1414 try:
# -> 1415     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416 except TypeError:
#    1417     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/axes/_base.py:4390, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4388         if ba:
#    4389             bb.append(ba)
# -> 4390 self._update_title_position(renderer)
#    4391 axbbox = self.get_window_extent(renderer)
#    4392 bb.append(axbbox)
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/axes/_base.py:2965, in _AxesBase._update_title_position(self, renderer)
#    2962 bb = None
#    2963 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2964         or ax.xaxis.get_label_position() == 'top'):
# -> 2965     bb = ax.xaxis.get_tightbbox(renderer)
#    2966 if bb is None:
#    2967     if 'outline' in ax.spines:
#    2968         # Special case for colorbars:
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/axis.py:1318, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1316 if renderer is None:
#    1317     renderer = self.figure._get_renderer()
# -> 1318 ticks_to_draw = self._update_ticks()
#    1320 self._update_label_position(renderer)
#    1322 # go back to just this axis's tick labels
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/axis.py:1258, in Axis._update_ticks(self)
#    1253 """
#    1254 Update ticks (position and labels) using the current data interval of
#    1255 the axes.  Return the list of ticks that will be drawn.
#    1256 """
#    1257 major_locs = self.get_majorticklocs()
# -> 1258 major_labels = self.major.formatter.format_ticks(major_locs)
#    1259 major_ticks = self.get_major_ticks(len(major_locs))
#    1260 self.major.formatter.set_locs(major_locs)
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/ticker.py:217, in Formatter.format_ticks(self, values)
#     215 def format_ticks(self, values):
#     216     """Return the tick labels for all the ticks at once."""
# --> 217     self.set_locs(values)
#     218     return [self(value, i) for i, value in enumerate(values)]
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/ticker.py:702, in ScalarFormatter.set_locs(self, locs)
#     700 if self._useOffset:
#     701     self._compute_offset()
# --> 702 self._set_order_of_magnitude()
#     703 self._set_format()
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/ticker.py:756, in ScalarFormatter._set_order_of_magnitude(self)
#     754     return
#     755 # restrict to visible ticks
# --> 756 vmin, vmax = sorted(self.axis.get_view_interval())
#     757 locs = np.asarray(self.locs)
#     758 locs = locs[(vmin <= locs) & (locs <= vmax)]
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/axis.py:2210, in _make_getset_interval.<locals>.getter(self)
#    2208 def getter(self):
#    2209     # docstring inherited.
# -> 2210     return getattr(getattr(self.axes, lim_name), attr_name)
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/axes/_base.py:857, in _AxesBase.viewLim(self)
#     855 @property
#     856 def viewLim(self):
# --> 857     self._unstale_viewLim()
#     858     return self._viewLim
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/axes/_base.py:844, in _AxesBase._unstale_viewLim(self)
#     841 def _unstale_viewLim(self):
#     842     # We should arrange to store this information once per share-group
#     843     # instead of on every axis.
# --> 844     need_scale = {
#     845         name: any(ax._stale_viewlims[name]
#     846                   for ax in self._shared_axes[name].get_siblings(self))
#     847         for name in self._axis_names}
#     848     if any(need_scale.values()):
#     849         for name in need_scale:
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/axes/_base.py:846, in <dictcomp>(.0)
#     841 def _unstale_viewLim(self):
#     842     # We should arrange to store this information once per share-group
#     843     # instead of on every axis.
#     844     need_scale = {
#     845         name: any(ax._stale_viewlims[name]
# --> 846                   for ax in self._shared_axes[name].get_siblings(self))
#     847         for name in self._axis_names}
#     848     if any(need_scale.values()):
#     849         for name in need_scale:
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:882, in Grouper.get_siblings(self, a)
#     880 def get_siblings(self, a):
#     881     """Return all of the items joined with *a*, including itself."""
# --> 882     self.clean()
#     883     siblings = self._mapping.get(weakref.ref(a), [weakref.ref(a)])
#     884     return [x() for x in siblings]
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:834, in Grouper.clean(self)
#     832 """Clean dead weak references from the dictionary."""
#     833 mapping = self._mapping
# --> 834 to_drop = [key for key in mapping if key() is None]
#     835 for key in to_drop:
#     836     val = mapping.pop(key)
#
# File ~/miniforge3/envs/torch/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:834, in <listcomp>(.0)
#     832 """Clean dead weak references from the dictionary."""
#     833 mapping = self._mapping
# --> 834 to_drop = [key for key in mapping if key() is None]
#     835 for key in to_drop:
#     836     val = mapping.pop(key)
#
# KeyboardInterrupt:
